# %%
import sys
import numpy as np
if "../" not in sys.path:
  sys.path.append("../") 
import os
os.chdir("..") 
from envs.data_handler import DataHandler
import envs.data_utils as du

dh = DataHandler(data_generation='LinearShifted', type='sqt')

# %% [markdown]
# Create non-stationary data using the ARCH model

# %%
non_stationary_data = du.create_non_stationary_data('ARCH', dh.data, N=300)
#non_stationary_data.to_csv('preparedData_ARCH_Id_sqt.csv')

# %% [markdown]
# Create non-stationary data using the GARCH model

# %%
non_stationary_data = du.create_non_stationary_data('GARCH', dh.data, N=300)
non_stationary_data.to_csv('preparedData_GARCH_Id_sqt.csv')

# %% [markdown]
# ## Ttest

# %%
dh = DataHandler(data_generation='ARCH', type='sqt')
# Out:
# preparedData_ARCH_Id_sqt.csv

# %%
ordering = du.get_ordering(dh.data)
result = du.perform_ttest(ordering, dh.data)
print(len(result[result['pvalue']<0.025]), 'of the ', len(result.index) ,' <component, failure> combination pairs are statistical significant')
# Out:
#                                                         sqt
# Optimal_Affected_Component_Uid Optimal_Failure
# _SEuUbecdEeet0YmmfbMwkw        CF3                 2.236068
# _SFKZ4-cdEeet0YmmfbMwkw        CF1                 2.236068
# _SFS8hucdEeet0YmmfbMwkw        CF1                 2.236068
# _SFLAj-cdEeet0YmmfbMwkw        CF1                 2.236068
#                                CF3                 2.236068
# ...                                                     ...
# _SFETHecdEeet0YmmfbMwkw        CF1               787.752128
# _SFLol-cdEeet0YmmfbMwkw        CF2               816.219452
# _SFE5xucdEeet0YmmfbMwkw        CF1               879.292262
# _SFETHecdEeet0YmmfbMwkw        CF3               895.875563
# _SFOrh-cdEeet0YmmfbMwkw        CF3              1026.530272
#
# [915 rows x 1 columns]
#        Optimal_Affected_Component_Uid Optimal_Failure     sqt
# 0             _SE-L2-cdEeet0YmmfbMwkw             CF1  4.0000
# ...
